# %%
# !dir
# Out:
# app    mongodb.py  requirements.txt  test_pipeline_sota.py
# db.py  pipeline    scripts

# %%
cd drive
# Out:
# /content/drive

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
cd capstone
# Out:
# /content/drive/MyDrive/capstone

# %%
cd natural-language-processing
# Out:
# /content/drive/MyDrive/capstone/natural-language-processing

# %%
# !pip install -r requirements.txt

# %%
import os

MONGO_URI="mongodb://rsrs-root:KIQu3jebjHNhTEE6mm5tgj2oNjYr7J805k2JLbE0AVo@35.86.219.39:27017/arxiv?authSource=admin"
MONGO_DB_NAME="arxiv"
MONGO_COLLECTION_NAME="papers"


os.environ["MONGO_URI"] = MONGO_URI
os.environ["MONGO_DB_NAME"] = MONGO_DB_NAME
os.environ["MONGO_COLLECTION"] = MONGO_COLLECTION

print("MONGO_URI   :", os.environ["MONGO_URI"])
print("DB_NAME     :", os.environ["MONGO_DB_NAME"])
print("COLLECTION  :", os.environ["MONGO_COLLECTION"])
# Out:
# MONGO_URI   : mongodb://rsrs-root:KIQu3jebjHNhTEE6mm5tgj2oNjYr7J805k2JLbE0AVo@35.86.219.39:27017/arxiv?authSource=admin
# DB_NAME     : arxiv
# COLLECTION  : papers

# %%
from pymongo import MongoClient
import os

client = MongoClient(os.environ["MONGO_URI"])
db = client[os.environ["MONGO_DB_NAME"]]
col = db[os.environ["MONGO_COLLECTION"]]

print("총 문서 수:", col.count_documents({}))
print("샘플 한 개:", col.find_one())
# Out:
# 총 문서 수: 2878313
# ...

# %%
# !python test_pipeline_sota.py
# Out:
# [DEBUG] sys.path added: /content/drive/MyDrive/capstone/natural-language-processing
# 2025-11-21 09:31:05.026134: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763717465.054194   37746 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763717465.060464   37746 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763717465.103583   37746 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
